# %%
from dotenv import load_dotenv
import os
from pyairtable import Api
from pyairtable.formulas import match
from datetime import datetime
from models import *
import pandas as pd
from pathlib import Path
import sys


load_dotenv()
KEY = os.getenv('KEY')
app = "app7KsgYl2jhOnYg7"

api = Api(KEY)
base = api.base(app)

home_dir = Path("../")
data_dir = home_dir / "data"
raw_dir = home_dir / "raw"

# %% [markdown]
# ## Formulae

# %%
def rxn_formula(rxn_name):
    return match({"rxn_name": rxn_name})

def tech_formula(tech_initials):
    return match({"initials": tech_initials})

def sample_formula(sample_id):
    match({"sample_id": sample_id})

def result_formula(reaction, well):
    return match({
        "reaction": reaction,
        "well": well,
    })

# %% [markdown]
# ## Get Reaction Names

# %%
reaction_list = list(raw_dir.rglob("*.xlsx"))
reactions = [file.name.replace(".xlsx", "") for file in reaction_list]

# %% [markdown]
# ## Find New Reactions to Upload to Airtable

# %%
# new_reactions = [
#     rxn
#     for rxn in reactions
#     if not Reaction.all(formula=rxn_formula(rxn)) 
# ]

# %% [markdown]
# ## Update Reaction Table

# %%
airtable_reactions = Reaction.all()

for rxn in reactions:

    rxn_split = rxn.split("_")

    assay = rxn_split[rxn.count("_")]
    
    date = rxn_split[0]
    date = "-".join([date[:4], date[4:6], date[6:8]])
    date = datetime.strptime(date, "%Y-%m-%d")

    reader = rxn_split[1]

    tech_initials = rxn_split[2]

    technician = [Technician.first(formula=tech_formula(tech_initials))]

    if not Reaction.first(formula=rxn_formula(rxn)):
        reaction = Reaction(
            rxn_name = rxn,
            assay = assay,
            date = date,
            technician = technician,
            reader = reader,
            temperature = 42
        )

        reaction.save()
    else:
        print(f"Entry already exists for rxn: {rxn}")
# Out:
# Entry already exists for rxn: 20250808_r12_GR_USDA-blood_Nano-QuIC
# Entry already exists for rxn: 20250808_r13_GR_USDA-blood_Nano-QuIC
# Entry already exists for rxn: 20250808_r2_GR_USDA-blood_RT-QuIC
# Entry already exists for rxn: 20250808_r3_GR_USDA-blood_RT-QuIC
# Entry already exists for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC
# Entry already exists for rxn: 20250818_r7_GR_USDA-blood_Nano-QuIC
# Entry already exists for rxn: 20251024_r8_GR_USDA-blood_2X_RT-QuIC
# Entry already exists for rxn: 20251024_r9_GR_USDA-blood_2X_Nano-QuIC
# Entry already exists for rxn: 20250714_r2_GR_USDA-LNs_RT-QuIC
# Entry already exists for rxn: 20250714_r3_GR_USDA-LNs_RT-QuIC
# Entry already exists for rxn: 20250714_r4_GR_USDA-LNs_RT-QuIC
# Entry already exists for rxn: 20250714_r7_GR_USDA-LNs_Nano-QuIC
# Entry already exists for rxn: 20250714_r8_GR_USDA-LNs_Nano-QuIC
# Entry already exists for rxn: 20250714_r9_GR_USDA-LNs_Nano-QuIC
# Entry already exists for rxn: 20250717_r2_GR_USDA-obex_RT-QuIC
# Entry already exists for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC
# Entry already exists for rxn: 20250717_r7_GR_USDA-obex_Nano-QuIC
# Entry already exists for rxn: 20250717_r8_GR_USDA-obex_Nano-QuIC
# Entry already exists for rxn: 20250819_r8_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250819_r9_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250821_r13_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250821_r1_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250821_r2_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250821_r6_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250903_r1_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250903_r2_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250903_r3_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250903_r4_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250912_r1_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250912_r2_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250912_r5_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250912_r7_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250916_r5_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250916_r7_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250923_r12_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250923_r14_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20250923_r1_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20250923_r6_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251001_r12_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251001_r14_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251001_r3_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251008_r12_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251008_r14_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251008_r1_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251008_r2_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251010_r3_GR_LN-obex_RT-QuIC
# Entry already exists for rxn: 20251010_r7_GR_LN-obex_Nano-QuIC
# Entry already exists for rxn: 20251021_r12_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251021_r14_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251021_r1_GR_LN_RT-QuIC
# Entry already exists for rxn: 20251021_r2_GR_LN_Nano-QuIC
# Entry already exists for rxn: 20251024_r10_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251024_r11_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251028_r12_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251028_r14_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251120_r12_SG_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251120_r14_SG_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251124_r3_SG_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251124_r4_SG_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251125_r12_GR_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251125_r14_GR_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251126_r5_SG_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251126_r6_SG_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251203_r4_SG_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC
# Entry already exists for rxn: 20251205_r2_SG_USDA-oral-swabs_Nano-QuIC
# Entry already exists for rxn: 20251216_r12_GR_RAMALT_RT-QuIC
# Entry already exists for rxn: 20251216_r14_GR_RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260108_r1_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260108_r2_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260109_r3_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260109_r4_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260112_r1_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260112_r2_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260113_r12_SG_RAMALT_RT-QuIC
# Entry already exists for rxn: 20260113_r13_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260114_r8_GR_RAMALT_RT-QuIC
# Entry already exists for rxn: 20260114_r9_GR_RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260115_r5_GR_RAMALT_RT-QuIC
# Entry already exists for rxn: 20260115_r7_GR_RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260116_r1_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260116_r2_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260120_r1_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260120_r2_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260121_r3_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260121_r5_GR_RAMALT_RT-QuIC
# Entry already exists for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260126_r1_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260126_r2_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260127_r3_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260127_r4_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260209_r3_GR_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260209_r4_GR_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260210_r10_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260210_r9_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260213_r10_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260213_r5_GR_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260213_r6_GR_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260218_r10_GR_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260218_r12_GR_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260218_r13_GR_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260218_r3_SG_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260218_r4_SG_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20260218_r8_GR_USDA-RAMALT_Nano-QuIC
# Entry already exists for rxn: 20260218_r9_GR_USDA-RAMALT_RT-QuIC
# Entry already exists for rxn: 20250919_r14_GR_serum-plasma_Nano-QuIC
# Entry already exists for rxn: 20250919_r6_GR_serum-plasma_RT-QuIC

# %% [markdown]
# ## Load in Results data

# %%
result_files = list(data_dir.rglob("calcs.parquet"))

df_list = []
for file in result_files:
    df = pd.read_parquet(file)
    df_list.append(df)
df = (
    pd
    .concat(df_list)
    .rename(columns={"Sample IDs": "sample_id"})
)

# %% [markdown]
# ## Find Reactions that don't have results yet.

# %%
samples = pd.DataFrame([
    {
        "id": sample.id,
        "sample_id": sample.sample_id
    }
    for sample in Sample.all()
])

rxns = pd.DataFrame([
    {
        "rxn_id": reaction.id,
        "rxn_name": reaction.rxn_name
    }
    for reaction in
    airtable_reactions
    # Reaction.all(formula=match({"results": ""}))
])
# new_reactions = new_reactions.rename(columns={'id':'rxn_id'})

# %%
# Make sure only samples that are listed on Airtable are being updated.
df_results = pd.merge(samples, df, "outer", on="sample_id")
# df_results = df_results[df_results['Reaction'].isin(rxns["rxn_name"])]
df_results = df_results.rename(columns={'Reaction': 'rxn_name', "Wells": "well", "Dilutions": "dilution"})
df_results = pd.merge(df_results, rxns, "outer", "rxn_name")

# %% [markdown]
# ## Update Results Table

# %%
def get_results(result):
    return {
        "result_id": result.id,
        "rxn_id": result.reaction[0].id,
        "well": result.well
    }
all_results = Result.all(fields=["reaction", "well"])
results = pd.DataFrame(map(get_results, all_results))

# %%
df_results = pd.merge(df_results, results, "outer", on=["rxn_id", "well"])

# %%
def get_sample(row):
    sample_id = row.get("id")
    sample_name = row.get("sample_id")
    if pd.isna(sample_id):
        print(f"No sample_id for sample: {sample_name}. Skipping.")
        return None
    return [Sample.from_id(sample_id)]

def get_reaction(row):
    rxn_id = row.get("rxn_id")
    rxn_name = row.get("rxn_name")
    if pd.isna(rxn_id):
        print(f"No rxn_id for rxn: {rxn_name}. Skipping.")
        return None
    return [Reaction.from_id(rxn_id)]

def get_metrics(row):
    return {    
        "well": row.get("well"),
        "dilution": row.get("dilution"),
        "mpr": row.get("MPR"),
        "ms": row.get("MS"),
        "ttt": row.get("TtT"),
        "raf": row.get("RAF"),
        "auc": row.get("AUC")
    }

def get_result(row):
    result_id = row.get("result_id")
    if pd.isna(result_id):
        return None
    return Result.from_id(result_id)

def update_result(row):
    metrics = get_metrics(row)
    result = get_result(row)
    if result:
        # print(f"Existing result found for rxn: {row.get('rxn_name')} and well: {metrics.get('well')}. Updating entry.")
        result.dilution = metrics.get("dilution")
        result.mpr = metrics.get("mpr")
        result.ms = metrics.get("ms")
        result.ttt = metrics.get("ttt")
        result.raf = metrics.get("raf")
        result.auc = metrics.get("auc")
    else:
        sample = get_sample(row)
        if not sample:
            return

        reaction = get_reaction(row)
        if not reaction:
            return

        print(f"No existing result for rxn: {row.get('rxn_name')} and well: {metrics.get('well')}. Creating new entry.")
        result = Result(
            sample = sample,
            reaction = reaction,
            dilution = metrics.get("dilution"),
            well = metrics.get("well"),
            mpr = metrics.get("mpr"),
            ms = metrics.get("ms"),
            ttt = metrics.get("ttt"),
            raf = metrics.get("raf"),
            auc = metrics.get("auc")
        )
    return result


update_results = df_results.apply(update_result, axis=1)
# Out:
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E05. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E06. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E07. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E08. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E09. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E10. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E11. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: E12. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F05. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F06. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F07. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F08. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F09. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F10. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F11. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: F12. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G05. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G06. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G07. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G08. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G09. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G10. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G11. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: G12. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H05. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H06. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H07. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H08. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H09. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H10. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H11. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20251205_r1_SG_USDA-oral-swabs_RT-QuIC and well: H12. Creating new entry.
# No sample_id for sample: EMPTY. Skipping.
# No existing result for rxn: 20
RT-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250717_r3_GR_USDA-obex_RT-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: A09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: B09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: C09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: D09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: E09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: F09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: G09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H02. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H03. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H04. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H05. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H06. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H07. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H08. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20250818_r5_GR_USDA-blood_RT-QuIC and well: H09. Creating new entry.
# No sample_id for sample: neg. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260213_r9_SG_USDA-RAMALT_RT-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260218_r7_GR_USDA-RAMALT_RT-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251203_r3_SG_USDA-oral-swabs_RT-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r4_SG_USDA-RAMALT_Nano-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260121_r7_GR_RAMALT_Nano-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: A01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: B01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: C01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: D01. Creating new entry.
# No sample_id for sample: P. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: E01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: F01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: G01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20251001_r4_GR_USDA-oral-swabs_Nano-QuIC and well: H01. Creating new entry.
# No sample_id for sample: N. Skipping.
# No existing result for rxn: 20260112_r2_SG_USDA-RAMALT_Nano-QuIC and well: A01. Creating new entry.
# ...
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.
# No existing result for rxn: nan and well: nan. Creating new entry.
# No rxn_id for rxn: nan. Skipping.

# %%
results_to_save = [result for result in update_results if result]

# %% [markdown]
# ## Save the Results

# %%
Result.batch_save(results_to_save)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 Result.batch_save(results_to_save)
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\pyairtable\orm\model.py:496, in Model.batch_save(cls, models)
#     489 update_records: List[UpdateRecordDict] = [
#     490     {"id": record["id"], "fields": record["fields"]}
#     491     for model in update_models
#     492     if (record := model.to_record(only_writable=True))
#     493 ]
#     495 if update_records:
# --> 496     cls.meta.table.batch_update(
#     497         update_records,
#     498         typecast=cls.meta.typecast,
#     499         use_field_ids=cls.meta.use_field_ids,
#     500     )
#     501 if create_records:
#     502     created_records = cls.meta.table.batch_create(
#     503         create_records,
#     504         typecast=cls.meta.typecast,
#     505         use_field_ids=cls.meta.use_field_ids,
#     506     )
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\pyairtable\api\table.py:490, in Table.batch_update(self, records, replace, typecast, use_field_ids)
#     488 for chunk in self.api.chunked(records):
#     489     chunk_records = [{"id": x["id"], "fields": x["fields"]} for x in chunk]
# --> 490     response = self.api.request(
#     491         method=method,
#     492         url=self.urls.records,
#     493         json={
#     494             "records": chunk_records,
#     495             "typecast": typecast,
#     496             "returnFieldsByFieldId": use_field_ids,
#     497         },
#     498     )
#     499     updated_records += assert_typed_dicts(RecordDict, response["records"])
#     501 return updated_records
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\pyairtable\api\api.py:289, in Api.request(self, method, url, fallback, options, params, json)
#     281     json, spare_params = options_to_json_and_params(options or {})
#     282     return self.request(
#     283         method=fallback[0],
#     284         url=fallback[1],
#     285         params={**spare_params, **(params or {})},
#     286         json=json,
#     287     )
# --> 289 response = self.session.request(
#     290     method=method,
#     291     url=url,
#     292     params=request_params,
#     293     json=json,
#     294 )
#     295 return self._process_response(response)
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\rowde002\Documents\Projects\usda-validation\.venv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
